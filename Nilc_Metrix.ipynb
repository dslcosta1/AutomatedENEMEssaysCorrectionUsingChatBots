# %%
from utils.nilc_nlp import *
from utils import dataset_setup
from utils.save_results import *

# %%
path_to = './data/'

# %%
"""
Setup Dataset
"""
dataset_name, dataset_code = dataset_setup.setup_dataset(3)
essays_dataset = dataset_setup.getDataset(path_to, dataset_name)
# Out:
# Dataset escolhido: propor2024

# %%
model_name = "nilc_metrix"
experiment_name = "exp0"

# %%
path_to_save = create_experiment_folder(path_to, model_name, experiment_name, dataset_name)
filename_to_save = build_filename_to_save(model_name, experiment_name, dataset_name, "0")
# Out:
# Folder './data/results/nilc_metrix' already exists.
# Folder './data/results/nilc_metrix/exp0' already exists.
# Folder './data/results/nilc_metrix/exp0/propor2024' already exists.
# CSV with the answer will be saved in: propor2024-nilc_metrix-exp0-0

# %%
len(essays_dataset)
# Out:
# 1155

# %%
essays_dataset[711]
# Out:
# {'id': '15.html',
#  'id_prompt': 'epidemia-alimentar-sobrepeso-e-obesidade',
#  'essay_title': 'A propaganda e o excesso de peso',
#  'essay_text': 'O mundo evoluiu, trazendo junto a sua evolução alguns problemas, dentre eles o sobrepeso e a obesidade que acomete crianças, adultos e idosos causando lhes sérios problemas de saúde que podem inclusive levar a morte. A organização mundial da saúde atribui o excesso de peso e a obesidade a vários fatores, e tem se preocupado em alertar a população a respeito disso, como a mesma já declarou: um desses fatores é a propaganda que exerce importante influência para o crescimento desses problemas. \nA alimentação é considerada a maior vilã de todo esse transtorno, mas outros agentes causadores desses problemas são: a genética, pois existe a questão da hereditariedade, a cultura, que depende do meio onde a pessoa está inserida e até a economia, no que diz respeito a falta de recursos para uma boa alimentação. Aliado a isso, somos bombardeados diariamente tanto nas redes sociais, como na televisão e nas ruas com propagandas de comidas nada saudáveis que acabam sendo irresistíveis e tentadoras.\nUm público alvo dessas propagandas são as crianças que não resistem a mistura prazerosa de açúcar, sal e gordura, quem não se lembra do comercial do Mc Donald`s, onde eles ofereciam brinquedos como brindes dentro do pacotinho de lanche como uma forma de atrai-los, muitos pais mesmo sabendo do risco fazem a vontade dos filhos, alguns cientes de que a longo prazo problemas de saúde podem aparecer, e quando estes aparecem são ali jogados fora toda uma infância, ou dependendo da situação toda uma vida.\nContudo, a criação de hábitos saudáveis começa em casa, com uma boa educação alimentar procurando atenuar ao máximo problemas de saúde futuros. Para combater a questão da desigualdade econômica e a cultura, os governos poderiam diminuir a taxação sobre alimentos saudáveis para que esses pudessem ser mais acessíveis a todos, e criar nas escola um programa que substitua a merenda escolar tradicional por uma mais saudável, fazer palestras e seminários com o tema e investir pesado em propagandas de incentivo a boa alimentação.',
#  'grades': '[160 120 160 120 160 720]',
#  'essay_year': '2018'}

# %%
start = 822
for i in range(start, len(essays_dataset)):
    
    essay_data = essays_dataset[i]
    essay_text = essay_data["essay_text"]
    essay_text = essay_text.replace("`", "")

    raw_output = run_text_metrics_docker(essay_text)
    metrics_dict = parse_metrics_output(raw_output)

    essay_data.update(metrics_dict)

    if (i == 0) :
        create_csv_header(path_to_save, filename_to_save, essay_data.keys())

    save_data(path_to_save, filename_to_save, [essay_data])

    print("Evaluated essay: " + str(i))
# Out:
# Evaluated essay: 822
# Evaluated essay: 823
# Evaluated essay: 824
# Evaluated essay: 825
# Evaluated essay: 826
# Evaluated essay: 827
# Evaluated essay: 828
# Evaluated essay: 829
# Evaluated essay: 830
# Evaluated essay: 831
# Evaluated essay: 832
# Evaluated essay: 833
# Evaluated essay: 834
# Evaluated essay: 835
# Evaluated essay: 836
# Evaluated essay: 837
# Evaluated essay: 838
# Evaluated essay: 839
# Evaluated essay: 840
# Evaluated essay: 841
# Evaluated essay: 842
# Evaluated essay: 843
# Evaluated essay: 844
# Evaluated essay: 845
# Evaluated essay: 846
# Evaluated essay: 847
# Evaluated essay: 848
# Evaluated essay: 849
# Evaluated essay: 850
# Evaluated essay: 851
# Evaluated essay: 852
# Evaluated essay: 853
# Evaluated essay: 854
# Evaluated essay: 855
# Evaluated essay: 856
# Evaluated essay: 857
# Evaluated essay: 858
# Evaluated essay: 859
# Evaluated essay: 860
# Evaluated essay: 861
# Evaluated essay: 862
# Evaluated essay: 863
# Evaluated essay: 864
# Evaluated essay: 865
# Evaluated essay: 866
# Evaluated essay: 867
# Evaluated essay: 868
# Evaluated essay: 869
# Evaluated essay: 870
# Evaluated essay: 871
# Evaluated essay: 872
# Evaluated essay: 873
# Evaluated essay: 874
# Evaluated essay: 875
# Evaluated essay: 876
# Evaluated essay: 877
# Evaluated essay: 878
# Evaluated essay: 879
# Evaluated essay: 880
# Evaluated essay: 881
# Evaluated essay: 882
# Evaluated essay: 883
# Evaluated essay: 884
# Evaluated essay: 885
# Evaluated essay: 886
# Evaluated essay: 887
# Evaluated essay: 888
# Evaluated essay: 889
# Evaluated essay: 890
# Evaluated essay: 891
# Evaluated essay: 892
# Evaluated essay: 893
# Evaluated essay: 894
# Evaluated essay: 895
# Evaluated essay: 896
# Evaluated essay: 897
# Evaluated essay: 898
# Evaluated essay: 899
# Evaluated essay: 900
# Evaluated essay: 901
# Evaluated essay: 902
# Evaluated essay: 903
# Evaluated essay: 904
# Evaluated essay: 905
# Evaluated essay: 906
# Evaluated essay: 907
# Evaluated essay: 908
# Evaluated essay: 909
# Evaluated essay: 910
# Evaluated essay: 911
# Evaluated essay: 912
# Evaluated essay: 913
# Evaluated essay: 914
# Evaluated essay: 915
# Evaluated essay: 916
# Evaluated essay: 917
# Evaluated essay: 918
# Evaluated essay: 919
# Evaluated essay: 920
# Evaluated essay: 921
# Evaluated essay: 922
# Evaluated essay: 923
# Evaluated essay: 924
# Evaluated essay: 925
# Evaluated essay: 926
# Evaluated essay: 927
# Evaluated essay: 928
# Evaluated essay: 929
# Evaluated essay: 930
# Evaluated essay: 931
# Evaluated essay: 932
# Evaluated essay: 933
# Evaluated essay: 934
# Evaluated essay: 935
# Evaluated essay: 936
# Evaluated essay: 937
# Evaluated essay: 938
# Evaluated essay: 939
# Evaluated essay: 940
# Evaluated essay: 941
# Evaluated essay: 942
# Evaluated essay: 943
# Evaluated essay: 944
# Evaluated essay: 945
# Evaluated essay: 946
# Evaluated essay: 947
# Evaluated essay: 948
# Evaluated essay: 949
# Evaluated essay: 950
# Evaluated essay: 951
# Evaluated essay: 952
# Evaluated essay: 953
# Evaluated essay: 954
# Evaluated essay: 955
# Evaluated essay: 956
# Evaluated essay: 957
# Evaluated essay: 958
# Evaluated essay: 959
# Evaluated essay: 960
# Evaluated essay: 961
# Evaluated essay: 962
# Evaluated essay: 963
# Evaluated essay: 964
# Evaluated essay: 965
# Evaluated essay: 966
# Evaluated essay: 967
# Evaluated essay: 968
# Evaluated essay: 969
# Evaluated essay: 970
# Evaluated essay: 971
# Evaluated essay: 972
# Evaluated essay: 973
# Evaluated essay: 974
# Evaluated essay: 975
# Evaluated essay: 976
# Evaluated essay: 977
# Evaluated essay: 978
# Evaluated essay: 979
# Evaluated essay: 980
# Evaluated essay: 981
# Evaluated essay: 982
# Evaluated essay: 983
# Evaluated essay: 984
# Evaluated essay: 985
# Evaluated essay: 986
# Evaluated essay: 987
# Evaluated essay: 988
# Evaluated essay: 989
# Evaluated essay: 990
# Evaluated essay: 991
# Evaluated essay: 992
# Evaluated essay: 993
# Evaluated essay: 994
# Evaluated essay: 995
# Evaluated essay: 996
# Evaluated essay: 997
# Evaluated essay: 998
# Evaluated essay: 999
# Evaluated essay: 1000
# Evaluated essay: 1001
# Evaluated essay: 1002
# Evaluated essay: 1003
# Evaluated essay: 1004
# Evaluated essay: 1005
# Evaluated essay: 1006
# Evaluated essay: 1007
# Evaluated essay: 1008
# Evaluated essay: 1009
# Evaluated essay: 1010
# Evaluated essay: 1011
# Evaluated essay: 1012
# Evaluated essay: 1013
# Evaluated essay: 1014
# Evaluated essay: 1015
# Evaluated essay: 1016
# Evaluated essay: 1017
# Evaluated essay: 1018
# Evaluated essay: 1019
# Evaluated essay: 1020
# Evaluated essay: 1021
# Evaluated essay: 1022
# Evaluated essay: 1023
# Evaluated essay: 1024
# Evaluated essay: 1025
# Evaluated essay: 1026
# Evaluated essay: 1027
# Evaluated essay: 1028
# Evaluated essay: 1029
# Evaluated essay: 1030
# Evaluated essay: 1031
# Evaluated essay: 1032
# Evaluated essay: 1033
# Evaluated essay: 1034
# Evaluated essay: 1035
# Evaluated essay: 1036
# Evaluated essay: 1037
# Evaluated essay: 1038
# Evaluated essay: 1039
# Evaluated essay: 1040
# Evaluated essay: 1041
# Evaluated essay: 1042
# Evaluated essay: 1043
# Evaluated essay: 1044
# Evaluated essay: 1045
# Evaluated essay: 1046
# Evaluated essay: 1047
# Evaluated essay: 1048
# Evaluated essay: 1049
# Evaluated essay: 1050
# Evaluated essay: 1051
# Evaluated essay: 1052
# Evaluated essay: 1053
# Evaluated essay: 1054
# Evaluated essay: 1055
# Evaluated essay: 1056
# Evaluated essay: 1057
# Evaluated essay: 1058
# Evaluated essay: 1059
# Evaluated essay: 1060
# Evaluated essay: 1061
# Evaluated essay: 1062
# Evaluated essay: 1063
# Evaluated essay: 1064
# Evaluated essay: 1065
# Evaluated essay: 1066
# Evaluated essay: 1067
# Evaluated essay: 1068
# Evaluated essay: 1069
# Evaluated essay: 1070
# Evaluated essay: 1071
# Evaluated essay: 1072
# Evaluated essay: 1073
# Evaluated essay: 1074
# Evaluated essay: 1075
# Evaluated essay: 1076
# Evaluated essay: 1077
# Evaluated essay: 1078
# Evaluated essay: 1079
# Evaluated essay: 1080
# Evaluated essay: 1081
# Evaluated essay: 1082
# Evaluated essay: 1083
# Evaluated essay: 1084
# Evaluated essay: 1085
# Evaluated essay: 1086
# Evaluated essay: 1087
# Evaluated essay: 1088
# Evaluated essay: 1089
# Evaluated essay: 1090
# Evaluated essay: 1091
# Evaluated essay: 1092
# Evaluated essay: 1093
# Evaluated essay: 1094
# Evaluated essay: 1095
# Evaluated essay: 1096
# Evaluated essay: 1097
# Evaluated essay: 1098
# Evaluated essay: 1099
# Evaluated essay: 1100
# Evaluated essay: 1101
# Evaluated essay: 1102
# Evaluated essay: 1103
# Evaluated essay: 1104
# Evaluated essay: 1105
# Evaluated essay: 1106
# Evaluated essay: 1107
# Evaluated essay: 1108
# Evaluated essay: 1109
# Evaluated essay: 1110
# Evaluated essay: 1111
# Evaluated essay: 1112
# Evaluated essay: 1113
# Evaluated essay: 1114
# Evaluated essay: 1115
# Evaluated essay: 1116
# Evaluated essay: 1117
# Evaluated essay: 1118
# Evaluated essay: 1119
# Evaluated essay: 1120
# Evaluated essay: 1121
# Evaluated essay: 1122
# Evaluated essay: 1123
# Evaluated essay: 1124
# Evaluated essay: 1125
# Evaluated essay: 1126
# Evaluated essay: 1127
# Evaluated essay: 1128
# Evaluated essay: 1129
# Evaluated essay: 1130
# Evaluated essay: 1131
# Evaluated essay: 1132
# Evaluated essay: 1133
# Evaluated essay: 1134
# Evaluated essay: 1135
# Evaluated essay: 1136
# Evaluated essay: 1137
# Evaluated essay: 1138
# Evaluated essay: 1139
# Evaluated essay: 1140
# Evaluated essay: 1141
# Evaluated essay: 1142
# Evaluated essay: 1143
# Evaluated essay: 1144
# Evaluated essay: 1145
# Evaluated essay: 1146
# Evaluated essay: 1147
# Evaluated essay: 1148
# Evaluated essay: 1149
# Evaluated essay: 1150
# Evaluated essay: 1151
# Evaluated essay: 1152
# Evaluated essay: 1153
# Evaluated essay: 1154
