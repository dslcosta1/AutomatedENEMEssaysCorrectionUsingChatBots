# %% [markdown]
# # Llama

# %%
from utils.model_setup import *
from utils.dataset_setup import *
from utils.experiment_setup import *
from utils.save_results import *
from utils.state_control import *
from utils.run_experiment import *

# %%
from importlib import reload

# %%
model_identifier = 'llama'
path_to = "./data/"
api_key = -1 # With value -1 it will change every 10 iterations

# %% [markdown]
# ## Setup

# %%
"""
Setup State
"""
use_experiment_state = True

state = create_state(-1, -1, -1, 1, 5, 0)
if use_experiment_state:
  state = retrieve_state(path_to, model_identifier)
# Out:
# {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 100}

# %%
execute_experiment(state, model_identifier, path_to, api_key)
# Out:
# Choosen Model: llama-3.2-90b-text-preview
#
#
#  Setting model llama-3.2-90b-text-preview with API Key -1
#
#
# Dataset escolhido: aes_enem_dataset
# Experimento escolhido: exp5
# Create exp5
# Prompt template:
# Qual o método de avaliação utilizado na correção de redações do ENEM?
#
# ####
#
# Corrija a redação abaixo seguindo o método de avaliação do ENEM. Atribuindo notas quantitativas entre 0 e 200 para cada uma das cinco competências. Forneça uma explicação detalhada que justifique cada nota.
#
#
# Tema:
# """
# <TEMA>
# """
#
#
# Redação:
# """
# <REDAÇÃO>
# """
#
# ####
# Não tenho dados adicionais que possam contribuir, use apenas a sua própria base de dados para fornecer as notas seguindo o formato do ENEM.
#
# Com os dados da reposta anterior, forneça apenas as notas quantitativas entre 0 e 200 para cada competência, e a nota final, no seguinte formato:[C1,C2,C3,C4,C5,Total], onde "Total" é a soma das notas das cinco competências.
#
# Não forneça texto na resposta, apenas as notas numéricas para competência e o total.
# {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 100}
# {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 100}
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 100}
#
#
# Execution number: 4
#
#
# Folder './data/results/llama-3.2-90b-text-preview' already exists.
# Folder './data/results/llama-3.2-90b-text-preview/exp5' already exists.
# Folder './data/results/llama-3.2-90b-text-preview/exp5/aes_enem_dataset' already exists.
# CSV with the answer will be saved in: aes_enem_dataset-llama-3.2-90b-text-preview-exp5-4
# It will evaluated essay with number:100
# Não tenho dados anteriores para fornecer notas. Essa é a minha primeira interação.
# Não há dados anteriores para trabalhar. Preciso de uma resposta anterior para fornecer as notas.
#
#  Não posso fornecer uma resposta.
# Evaluated essay with number: 100
# It will evaluated essay with number:101
# Não posso fornecer notas pois não há resposta anterior.
# Evaluated essay with number: 101
# It will evaluated essay with number:102
# Evaluated essay with number: 102
# It will evaluated essay with number:103
# Evaluated essay with number: 103
# It will evaluated essay with number:104
# Evaluated essay with number: 104
# It will evaluated essay with number:105
# Não posso fornecer essas informações.
# Evaluated essay with number: 105
# It will evaluated essay with number:106
# Evaluated essay with number: 106
# It will evaluated essay with number:107
# Evaluated essay with number: 107
# It will evaluated essay with number:108
# 0
# Não é possível fornecer uma resposta precisa, pois não há informações suficientes. Para calcular as notas precisaria das respostas dadas em provas de cada competência.
# Não há informações suficientes para calcular as notas.
# Evaluated essay with number: 108
# It will evaluated essay with number:109
# Evaluated essay with number: 109
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 2
#
#
# Processed essays from 100 to: 110
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 110}
# It will evaluated essay with number:110
# Evaluated essay with number: 110
# It will evaluated essay with number:111
# Evaluated essay with number: 111
# It will evaluated essay with number:112
# Evaluated essay with number: 112
# It will evaluated essay with number:113
# Infelizmente, não posso fornecer notas quantitativas sem ter acesso a uma resposta anterior. A solicitação foi feita sem fornecer informações ou contextos que permitiriam calcular as notas.
#
# Os dados necessários para calcular as notas não foram fornecidos ou registrados anteriormente.
# Nesse caso, como não há dados para avaliar, não posso fornecer notas.
# Evaluated essay with number: 113
# It will evaluated essay with number:114
# Evaluated essay with number: 114
# It will evaluated essay with number:115
# Evaluated essay with number: 115
# It will evaluated essay with number:116
# Evaluated essay with number: 116
# It will evaluated essay with number:117
# Evaluated essay with number: 117
# It will evaluated essay with number:118
# Evaluated essay with number: 118
# It will evaluated essay with number:119
# Evaluated essay with number: 119
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 3
#
#
# Processed essays from 110 to: 120
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 120}
# It will evaluated essay with number:120
# Evaluated essay with number: 120
# It will evaluated essay with number:121
# Evaluated essay with number: 121
# It will evaluated essay with number:122
# Evaluated essay with number: 122
# It will evaluated essay with number:123
# Infelizmente, não há dados para fornecer notas.
# Evaluated essay with number: 123
# It will evaluated essay with number:124
# Evaluated essay with number: 124
# It will evaluated essay with number:125
# Como não há dados anteriores, não posso fornecer notas.
# Evaluated essay with number: 125
# It will evaluated essay with number:126
# Não tenho acesso a nenhuma reposta anterior, pois esta é a primeira interação. Portanto, não posso fornecer notas baseadas em nenhuma informação anterior.
#
# Se você quiser, posso fornecer notas aleatórias para cada competência e o total, mas tenha em mente que essas notas não teriam qualquer significado real.
#
# [Aguardando instruções...]
# Evaluated essay with number: 126
# It will evaluated essay with number:127
# Evaluated essay with number: 127
# It will evaluated essay with number:128
# Evaluated essay with number: 128
# It will evaluated essay with number:129
# Evaluated essay with number: 129
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 4
#
#
# Processed essays from 120 to: 130
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 130}
# It will evaluated essay with number:130
# Evaluated essay with number: 130
# It will evaluated essay with number:131
# Evaluated essay with number: 131
# It will evaluated essay with number:132
# Evaluated essay with number: 132
# It will evaluated essay with number:133
# Evaluated essay with number: 133
# It will evaluated essay with number:134
# Evaluated essay with number: 134
# It will evaluated essay with number:135
# Desculpe, mas não há resposta anterior para fornecer as notas. Esta é a primeira interação.
#
# Aguardando mais informações...
# Essa é uma pergunta sem dados ou respostas anteriores. Infelizmente, não posso fornecer notas sem um conteúdo para avaliar.
# Evaluated essay with number: 135
# It will evaluated essay with number:136
# Evaluated essay with number: 136
# It will evaluated essay with number:137
# Evaluated essay with number: 137
# It will evaluated essay with number:138
# Evaluated essay with number: 138
# It will evaluated essay with number:139
# Evaluated essay with number: 139
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 5
#
#
# Processed essays from 130 to: 140
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 140}
# It will evaluated essay with number:140
# Não tenho informações suficientes para fornecer uma resposta.
# Evaluated essay with number: 140
# It will evaluated essay with number:141
# Evaluated essay with number: 141
# It will evaluated essay with number:142
# Evaluated essay with number: 142
# It will evaluated essay with number:143
# Evaluated essay with number: 143
# It will evaluated essay with number:144
# Evaluated essay with number: 144
# It will evaluated essay with number:145
# Evaluated essay with number: 145
# It will evaluated essay with number:146
# Evaluated essay with number: 146
# It will evaluated essay with number:147
# Evaluated essay with number: 147
# It will evaluated essay with number:148
# Evaluated essay with number: 148
# It will evaluated essay with number:149
# Evaluated essay with number: 149
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 1
#
#
# Processed essays from 140 to: 150
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 150}
# It will evaluated essay with number:150
# Evaluated essay with number: 150
# It will evaluated essay with number:151
# Evaluated essay with number: 151
# It will evaluated essay with number:152
# Infelizmente, não tenho dados para fornecer notas. Gostaria de fazer uma questão para você responder e então calculate as notas?
# Evaluated essay with number: 152
# It will evaluated essay with number:153
# Não é possível fornecer notas sem dados adicionais. Não há dados para avaliar.
# Não tenho dados para fornecer notas.
# Como não houve resposta anterior, não posso fornecer notas. Se você quiser fornecer a resposta ou o texto original, posso avaliá-lo e fornecer as notas no formato solicitado.
# Não tenho dados suficientes para fornecer notas.
# Evaluated essay with number: 153
# It will evaluated essay with number:154
# Evaluated essay with number: 154
# It will evaluated essay with number:155
# Não posso fornecer notas quantitativas sem ter recebido nenhuma informação anterior. Essa não é uma sequência contínua, faltam os dados da resposta anterior.
#
# Por favor, forneça a resposta anterior para que eu possa calcular as notas corretas.
# Evaluated essay with number: 155
# It will evaluated essay with number:156
# Evaluated essay with number: 156
# It will evaluated essay with number:157
# Evaluated essay with number: 157
# It will evaluated essay with number:158
# Evaluated essay with number: 158
# It will evaluated essay with number:159
# Não há resposta anterior para fornecer notas com base nela. Ficarei feliz em ajudar com uma nova questão ou tarefa.
# Evaluated essay with number: 159
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 2
#
#
# Processed essays from 150 to: 160
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 160}
# It will evaluated essay with number:160
# Não posso fornecer uma resposta correta já que não tenho os dados necessários para avaliar as competências.
# Evaluated essay with number: 160
# It will evaluated essay with number:161
# Evaluated essay with number: 161
# It will evaluated essay with number:162
# Não há uma resposta anterior disponível.
# Impossível fornecer as notas sem dados para avaliar.
# Evaluated essay with number: 162
# It will evaluated essay with number:163
# Desculpe, mas não há dados disponíveis para fornecer as notas.
# Evaluated essay with number: 163
# It will evaluated essay with number:164
# Evaluated essay with number: 164
# It will evaluated essay with number:165
# Não é possível fornecer notas sem informações sobre o desempenho ou o conteúdo avaliado.
# Evaluated essay with number: 165
# It will evaluated essay with number:166
# Evaluated essay with number: 166
# It will evaluated essay with number:167
# Evaluated essay with number: 167
# It will evaluated essay with number:168
# Não há dados suficientes para calcular as notas.
# Evaluated essay with number: 168
# It will evaluated essay with number:169
# Não há dados anteriores para fornecer notas, portanto, não posso gerar notas quantitativas.
# Evaluated essay with number: 169
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 3
#
#
# Processed essays from 160 to: 170
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 170}
# It will evaluated essay with number:170
# Evaluated essay with number: 170
# It will evaluated essay with number:171
# Evaluated essay with number: 171
# It will evaluated essay with number:172
# Não tenho dados anteriores para calcular as notas.
# Não tenho informações para fornecer notas.
# Evaluated essay with number: 172
# It will evaluated essay with number:173
# Não há dados suficientes para fornecer notas. Como não há resposta anterior, não posso fornecer notas.
# Não tenho informações para fornecer notas.
# Evaluated essay with number: 173
# It will evaluated essay with number:174
# 500
# Evaluated essay with number: 174
# It will evaluated essay with number:175
# Não há uma resposta anterior para fornecer as notas.
# Não é possível fornecer uma resposta numérica sem qualquer dado ou contexto. Reunião é necessária para fornecer uma resposta precisa.
# Não há dados suficientes para fornecer notas. Não é possível calcular as notas sem informações adicionais.
# 600
# Não é possível fornecer notas quantitativas sem ter informações sobre as respostas anteriores ou sobre o desempenho do aluno. A solicitação anterior não foi registrada.
# Evaluated essay with number: 175
# It will evaluated essay with number:176
# Evaluated essay with number: 176
# It will evaluated essay with number:177
# Sem dados da resposta anterior, não posso fornecer as notas. Por favor, forneça a resposta anterior para que eu possa calcular as notas.
# Não tenho dados para fornecer notas quantitativas.
# Não há resposta anterior para fornecer as notas. Não posso fornecer notas sem avaliação ou conteúdo prévio.
# Evaluated essay with number: 177
# It will evaluated essay with number:178
# Evaluated essay with number: 178
# It will evaluated essay with number:179
# Não há nota para fornecer, pois não houve resposta anterior para calcular as notas.
# Evaluated essay with number: 179
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 4
#
#
# Processed essays from 170 to: 180
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 180}
# It will evaluated essay with number:180
# Evaluated essay with number: 180
# It will evaluated essay with number:181
# Sem dados adicionais, não posso fornecer uma resposta precisa. Agradeço a oportunidade de auxiliar e aguardo mais informações para uma resposta precisa.
#
# Não posso fornecer uma resposta que segue os padrões solicitados sem os dados necessários.
# Não tenho dados para fornecer notas.
# Evaluated essay with number: 181
# It will evaluated essay with number:182
# Evaluated essay with number: 182
# It will evaluated essay with number:183
# Evaluated essay with number: 183
# It will evaluated essay with number:184
# Evaluated essay with number: 184
# It will evaluated essay with number:185
# Evaluated essay with number: 185
# It will evaluated essay with number:186
# Não há dados suficientes para fornecer notas.
# Não posso fornecer respostas específicas sem dados de entrada.
# Evaluated essay with number: 186
# It will evaluated essay with number:187
# Evaluated essay with number: 187
# It will evaluated essay with number:188
# Evaluated essay with number: 188
# It will evaluated essay with number:189
# Evaluated essay with number: 189
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 5
#
#
# Processed essays from 180 to: 190
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 190}
# It will evaluated essay with number:190
# Evaluated essay with number: 190
# It will evaluated essay with number:191
# Não disponho de informações para fornecer notas.
# Evaluated essay with number: 191
# It will evaluated essay with number:192
# Evaluated essay with number: 192
# It will evaluated essay with number:193
# Evaluated essay with number: 193
# It will evaluated essay with number:194
# Evaluated essay with number: 194
# It will evaluated essay with number:195
# Evaluated essay with number: 195
# It will evaluated essay with number:196
# Evaluated essay with number: 196
# It will evaluated essay with number:197
# Como não há dados adicionais disponíveis na resposta anterior, não posso fornecer notas quantitativas. Portanto, a resposta é:
#
# [Não é possível fornecer notas sem dados adicionais.]
# Não posso fornecer as notas pois não há dados da resposta anterior para realizar essa informação.
# Não posso fornecer notas sem ter um texto para avaliar. Como não há texto anterior, não posso fornecer notas.
#
# Se você fornecer um texto, posso sim avaliá-lo e fornecer as notas de acordo com as competências do ENEM.
# Evaluated essay with number: 197
# It will evaluated essay with number:198
# Evaluated essay with number: 198
# It will evaluated essay with number:199
# Evaluated essay with number: 199
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 1
#
#
# Processed essays from 190 to: 200
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 200}
# It will evaluated essay with number:200
# Evaluated essay with number: 200
# It will evaluated essay with number:201
# Evaluated essay with number: 201
# It will evaluated essay with number:202
# Desculpe, mas como não há dados da resposta anterior para utilizar, não posso fornecer notas quantitativas. Se você deseja, eu posso responder a uma pergunta específica para gerar esses dados.
# Evaluated essay with number: 202
# It will evaluated essay with number:203
# Infelizmente, não tenho dados suficientes para fornecer notas quantitativas. Não houve resposta anterior para que eu possa calcular as notas.
#
# Para fornecer uma resposta, preciso de mais informações. Se você tiver alguma questão específica ou desejar responder a algumas perguntas para que eu possa calcular as notas, estou à disposição.
# Evaluated essay with number: 203
# It will evaluated essay with number:204
# Evaluated essay with number: 204
# It will evaluated essay with number:205
# Sem dados anteriores, não é possível fornecer notas.
# Evaluated essay with number: 205
# It will evaluated essay with number:206
# Evaluated essay with number: 206
# It will evaluated essay with number:207
# Evaluated essay with number: 207
# It will evaluated essay with number:208
# Evaluated essay with number: 208
# It will evaluated essay with number:209
# Evaluated essay with number: 209
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 2
#
#
# Processed essays from 200 to: 210
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 4, 'MaxExecucao': 5, 'Batch': 210}
# End value is:  210
# Limit value is: 216
# It will evaluated essay with number:210
# Evaluated essay with number: 210
# It will evaluated essay with number:211
# Evaluated essay with number: 211
# It will evaluated essay with number:212
# Evaluated essay with number: 212
# It will evaluated essay with number:213
# Evaluated essay with number: 213
# It will evaluated essay with number:214
# Evaluated essay with number: 214
# It will evaluated essay with number:215
# Evaluated essay with number: 215
# Processed essays from 210 to: 216
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 0}
#
#
# Execution number: 5
#
#
# Folder './data/results/llama-3.2-90b-text-preview' already exists.
# Folder './data/results/llama-3.2-90b-text-preview/exp5' already exists.
# Folder './data/results/llama-3.2-90b-text-preview/exp5/aes_enem_dataset' already exists.
# CSV with the answer will be saved in: aes_enem_dataset-llama-3.2-90b-text-preview-exp5-5
# It will evaluated essay with number:0
# Evaluated essay with number: 0
# It will evaluated essay with number:1
# Não tenho informações suficientes para fornecer as notas.
# Evaluated essay with number: 1
# It will evaluated essay with number:2
# Evaluated essay with number: 2
# It will evaluated essay with number:3
# Evaluated essay with number: 3
# It will evaluated essay with number:4
# Evaluated essay with number: 4
# It will evaluated essay with number:5
# Evaluated essay with number: 5
# It will evaluated essay with number:6
# Evaluated essay with number: 6
# It will evaluated essay with number:7
# Informação insuficiente para calcular notas.
# Evaluated essay with number: 7
# It will evaluated essay with number:8
# Não foi fornecida nenhuma resposta anterior, portanto, não posso fornecer notas.
# Evaluated essay with number: 8
# It will evaluated essay with number:9
# Evaluated essay with number: 9
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 2
#
#
# Processed essays from 0 to: 10
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 10}
# It will evaluated essay with number:10
# Não há dados suficientes para fornecer notas.
# Evaluated essay with number: 10
# It will evaluated essay with number:11
# Evaluated essay with number: 11
# It will evaluated essay with number:12
# Não há dados anteriores para calcular as notas. Não posso fornecer uma resposta válida. Caso deseje, posso ajudá-lo com algo mais.
# Evaluated essay with number: 12
# It will evaluated essay with number:13
# Evaluated essay with number: 13
# It will evaluated essay with number:14
# Não há dados suficientes para fornecer as notas.
# Não há dados anterior para fornecer as notas.
#  impossível fornecer respostas quantitativas sem dados iniciais.
# Sem dados anteriores, não posso fornecer notas quantitativas.
# Evaluated essay with number: 14
# It will evaluated essay with number:15
# Evaluated essay with number: 15
# It will evaluated essay with number:16
# Não há dados disponíveis para fornecer notas.
# Não tenho dados suficientes para fornecer as notas.
# Evaluated essay with number: 16
# It will evaluated essay with number:17
# Evaluated essay with number: 17
# It will evaluated essay with number:18
# Evaluated essay with number: 18
# It will evaluated essay with number:19
# Evaluated essay with number: 19
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 3
#
#
# Processed essays from 10 to: 20
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 20}
# It will evaluated essay with number:20
# 0 para todas as competências, 0
# Evaluated essay with number: 20
# It will evaluated essay with number:21
# Evaluated essay with number: 21
# It will evaluated essay with number:22
# Evaluated essay with number: 22
# It will evaluated essay with number:23
# Evaluated essay with number: 23
# It will evaluated essay with number:24
# Evaluated essay with number: 24
# It will evaluated essay with number:25
# Evaluated essay with number: 25
# It will evaluated essay with number:26
# Não tenho informações suficientes para fornecer as notas.
# Evaluated essay with number: 26
# It will evaluated essay with number:27
# Evaluated essay with number: 27
# It will evaluated essay with number:28
# Evaluated essay with number: 28
# It will evaluated essay with number:29
# Não tenho dados para fornecer notas.
# Evaluated essay with number: 29
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 4
#
#
# Processed essays from 20 to: 30
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 30}
# It will evaluated essay with number:30
# Não tenho dados anteriores para processar.
# Não há dados anteriores, portanto não é possível fornecer notas quantitativas.
# Evaluated essay with number: 30
# It will evaluated essay with number:31
# Evaluated essay with number: 31
# It will evaluated essay with number:32
# Não há dados para fornecer notas.
# Evaluated essay with number: 32
# It will evaluated essay with number:33
# Evaluated essay with number: 33
# It will evaluated essay with number:34
# Evaluated essay with number: 34
# It will evaluated essay with number:35
# Não tenho informações suficientes para fornecer as notas quantitativas.
# Evaluated essay with number: 35
# It will evaluated essay with number:36
# Desculpe, mas não há dados anteriores para calcular as notas. Para fornecer as notas, preciso de uma resposta anterior que contenha dados ou informações para calcular as notas. Não há informação suficiente para fornecer as notas no formato solicitado.
# Evaluated essay with number: 36
# It will evaluated essay with number:37
# Evaluated essay with number: 37
# It will evaluated essay with number:38
# Não há dados anteriores para fornecer notas.
# Evaluated essay with number: 38
# It will evaluated essay with number:39
# Não há resposta anterior para referenciar. Não posso fornecer notas sem uma base para isso.
# Evaluated essay with number: 39
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 5
#
#
# Processed essays from 30 to: 40
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 40}
# It will evaluated essay with number:40
# Evaluated essay with number: 40
# It will evaluated essay with number:41
# Não foi fornecida nenhuma resposta anterior para calcular as notas. Portanto, não posso fornecer as notas no formato solicitado.
# Evaluated essay with number: 41
# It will evaluated essay with number:42
# Evaluated essay with number: 42
# It will evaluated essay with number:43
# Evaluated essay with number: 43
# It will evaluated essay with number:44
# Evaluated essay with number: 44
# It will evaluated essay with number:45
# Evaluated essay with number: 45
# It will evaluated essay with number:46
# [450]
# Evaluated essay with number: 46
# It will evaluated essay with number:47
# Não há dados suficientes para fornecer as notas.
# Evaluated essay with number: 47
# It will evaluated essay with number:48
# Evaluated essay with number: 48
# It will evaluated essay with number:49
# Evaluated essay with number: 49
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 1
#
#
# Processed essays from 40 to: 50
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 50}
# It will evaluated essay with number:50
# Evaluated essay with number: 50
# It will evaluated essay with number:51
# Evaluated essay with number: 51
# It will evaluated essay with number:52
# Evaluated essay with number: 52
# It will evaluated essay with number:53
# Evaluated essay with number: 53
# It will evaluated essay with number:54
# Evaluated essay with number: 54
# It will evaluated essay with number:55
# Evaluated essay with number: 55
# It will evaluated essay with number:56
# Não há dados anteriores para avaliar.
# Nenhuma resposta foi fornecida anteriormente, portanto, não é possível fornecer notas quantitativas.
# Evaluated essay with number: 56
# It will evaluated essay with number:57
# Evaluated essay with number: 57
# It will evaluated essay with number:58
# Não há dados suficientes para calcular as notas.
# Evaluated essay with number: 58
# It will evaluated essay with number:59
# Evaluated essay with number: 59
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 2
#
#
# Processed essays from 50 to: 60
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 60}
# It will evaluated essay with number:60
# Evaluated essay with number: 60
# It will evaluated essay with number:61
# Não disponho de informações suficientes para fornecer uma resposta precisa. Não posso gerar notas sem um texto de referência para avaliar.
# Evaluated essay with number: 61
# It will evaluated essay with number:62
# [Sem dados para fornecer notas]
# Evaluated essay with number: 62
# It will evaluated essay with number:63
# Evaluated essay with number: 63
# It will evaluated essay with number:64
# Evaluated essay with number: 64
# It will evaluated essay with number:65
# Evaluated essay with number: 65
# It will evaluated essay with number:66
# Evaluated essay with number: 66
# It will evaluated essay with number:67
# Não há dados disponíveis para fornecer notas.
# Evaluated essay with number: 67
# It will evaluated essay with number:68
# Evaluated essay with number: 68
# It will evaluated essay with number:69
# Evaluated essay with number: 69
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 3
#
#
# Processed essays from 60 to: 70
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 70}
# It will evaluated essay with number:70
# Não posso fornecer notas sem ter acesso a qualquer tipo de dado ou resposta anterior. Não há informações disponíveis para processar.
#
# Aguardo mais instruções ou informações para continuar.
# Nenhuma informação disponível.
# Evaluated essay with number: 70
# It will evaluated essay with number:71
# Evaluated essay with number: 71
# It will evaluated essay with number:72
# Evaluated essay with number: 72
# It will evaluated essay with number:73
# Não posso fornecer notas sem uma prova ou uma resposta anterior para avaliar.
# Evaluated essay with number: 73
# It will evaluated essay with number:74
# Evaluated essay with number: 74
# It will evaluated essay with number:75
# Evaluated essay with number: 75
# It will evaluated essay with number:76
# Não tenho dados suficientes para fornecer notas.
# Evaluated essay with number: 76
# It will evaluated essay with number:77
# Evaluated essay with number: 77
# It will evaluated essay with number:78
# Não é possível fornecer notas sem ter acesso a informações ou respostas anteriores.
# Evaluated essay with number: 78
# It will evaluated essay with number:79
# Não há dados para fornecer notas.
# _sem notas para fornecer_
# Não tenho informações para fornecer notas.
# Evaluated essay with number: 79
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 4
#
#
# Processed essays from 70 to: 80
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 80}
# It will evaluated essay with number:80
# Evaluated essay with number: 80
# It will evaluated essay with number:81
# Não tenho dados suficientes para fornecer notas.
# Não é possível fornecer as notas sem ter acesso aos dados da resposta anterior. Como não há dados fornecidos, não posso calcular as notas.
# Evaluated essay with number: 81
# It will evaluated essay with number:82
# Evaluated essay with number: 82
# It will evaluated essay with number:83
# Não há uma resposta anterior para se basear.
# Evaluated essay with number: 83
# It will evaluated essay with number:84
# Evaluated essay with number: 84
# It will evaluated essay with number:85
# Evaluated essay with number: 85
# It will evaluated essay with number:86
# Evaluated essay with number: 86
# It will evaluated essay with number:87
# [NA, NA, NA, NA, NA, 0]
# Evaluated essay with number: 87
# It will evaluated essay with number:88
# Evaluated essay with number: 88
# It will evaluated essay with number:89
# Evaluated essay with number: 89
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 5
#
#
# Processed essays from 80 to: 90
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 90}
# It will evaluated essay with number:90
# Como não há dados anteriores, não posso fornecer notas.
# Evaluated essay with number: 90
# It will evaluated essay with number:91
# Evaluated essay with number: 91
# It will evaluated essay with number:92
# Não há dados anteriores para calcular as notas. Consulte novamente com uma resposta anterior.
# Evaluated essay with number: 92
# It will evaluated essay with number:93
# Evaluated essay with number: 93
# It will evaluated essay with number:94
# Evaluated essay with number: 94
# It will evaluated essay with number:95
# Evaluated essay with number: 95
# It will evaluated essay with number:96
# Como não foi fornecida nenhuma resposta anterior, não é possível calcular as notas. Para fornecer as notas, preciso de uma resposta ou texto para avaliar.
# Não tenho dados para fornecer notas.
# Não há dados disponíveis para fornecer as notas.
# Não há resposta anterior para se basear. Como não há informações suficientes, não posso fornecer uma resposta no formato solicitado.
# Evaluated essay with number: 96
# It will evaluated essay with number:97
# Não posso fornecer não há dados disponíveis para calcular as notas.
# Evaluated essay with number: 97
# It will evaluated essay with number:98
# Evaluated essay with number: 98
# It will evaluated essay with number:99
# Sem dados prévios para acessar, não é possível calcular as notas.
# Evaluated essay with number: 99
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 1
#
#
# Processed essays from 90 to: 100
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 100}
# It will evaluated essay with number:100
# Evaluated essay with number: 100
# It will evaluated essay with number:101
# Evaluated essay with number: 101
# It will evaluated essay with number:102
# Evaluated essay with number: 102
# It will evaluated essay with number:103
# Evaluated essay with number: 103
# It will evaluated essay with number:104
# Evaluated essay with number: 104
# It will evaluated essay with number:105
# Evaluated essay with number: 105
# It will evaluated essay with number:106
# Evaluated essay with number: 106
# It will evaluated essay with number:107
# Evaluated essay with number: 107
# It will evaluated essay with number:108
# Evaluated essay with number: 108
# It will evaluated essay with number:109
# Evaluated essay with number: 109
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 2
#
#
# Processed essays from 100 to: 110
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 110}
# It will evaluated essay with number:110
# Evaluated essay with number: 110
# It will evaluated essay with number:111
# Evaluated essay with number: 111
# It will evaluated essay with number:112
# Evaluated essay with number: 112
# It will evaluated essay with number:113
# Evaluated essay with number: 113
# It will evaluated essay with number:114
# Evaluated essay with number: 114
# It will evaluated essay with number:115
# Evaluated essay with number: 115
# It will evaluated essay with number:116
# Evaluated essay with number: 116
# It will evaluated essay with number:117
# Evaluated essay with number: 117
# It will evaluated essay with number:118
# Evaluated essay with number: 118
# It will evaluated essay with number:119
# Sem resposta anterior, não posso fornecer notas.
# Evaluated essay with number: 119
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 3
#
#
# Processed essays from 110 to: 120
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 120}
# It will evaluated essay with number:120
# Evaluated essay with number: 120
# It will evaluated essay with number:121
# Evaluated essay with number: 121
# It will evaluated essay with number:122
# Evaluated essay with number: 122
# It will evaluated essay with number:123
# Evaluated essay with number: 123
# It will evaluated essay with number:124
# Evaluated essay with number: 124
# It will evaluated essay with number:125
# Infelizmente não há dados suficientes para fornecer uma resposta.
# Evaluated essay with number: 125
# It will evaluated essay with number:126
# Evaluated essay with number: 126
# It will evaluated essay with number:127
# Evaluated essay with number: 127
# It will evaluated essay with number:128
# Evaluated essay with number: 128
# It will evaluated essay with number:129
# Infelizmente, como não há informações anteriores para avaliar, não é possível fornecer as notas quantitativas.
# Não há resposta anterior para utilizar como base, portanto, não posso fornecer notas.
# Evaluated essay with number: 129
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 4
#
#
# Processed essays from 120 to: 130
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 130}
# It will evaluated essay with number:130
# Evaluated essay with number: 130
# It will evaluated essay with number:131
# Evaluated essay with number: 131
# It will evaluated essay with number:132
# Não há dados anteriores para fornecer notas. A resposta não pode ser gerada.
# Evaluated essay with number: 132
# It will evaluated essay with number:133
# Não é possível fornecer notas quantitativas sem um texto ou dados de entrada.
# Nenhuma informação disponível para fornecer notas.
# Evaluated essay with number: 133
# It will evaluated essay with number:134
# Não há nenhuma resposta anterior para basear as notas.
# Evaluated essay with number: 134
# It will evaluated essay with number:135
# Evaluated essay with number: 135
# It will evaluated essay with number:136
# Evaluated essay with number: 136
# It will evaluated essay with number:137
# Evaluated essay with number: 137
# It will evaluated essay with number:138
# Evaluated essay with number: 138
# It will evaluated essay with number:139
# Não foi possível fornecer as notas, pois não houve resposta anterior com base para calculá-las.
# Infelizmente, não há dados suficientes para fornecer notas quantitativas. Não posso fornecer notas baseado em dados inexistentes.
# Evaluated essay with number: 139
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 5
#
#
# Processed essays from 130 to: 140
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 140}
# It will evaluated essay with number:140
# Evaluated essay with number: 140
# It will evaluated essay with number:141
# Evaluated essay with number: 141
# It will evaluated essay with number:142
#  Não tenho dados suficientes para fornecer as notas.
# Essa é a primeira pergunta da interação. Não há dados anteriores para calcular as notas. Não posso fornecer notas sem dados.
# Não posso fornecer notas sem uma avaliação prévia.
# Infelizmente, não posso fornecer notas pois não houve resposta anterior.
# Evaluated essay with number: 142
# It will evaluated essay with number:143
# Evaluated essay with number: 143
# It will evaluated essay with number:144
# Evaluated essay with number: 144
# It will evaluated essay with number:145
# Evaluated essay with number: 145
# It will evaluated essay with number:146
# Infelizmente, não tenho os dados da resposta anterior para fornecer as notas. Se quiser fornecer os dados ou fazer uma nova pergunta, posso ajudar.
# Evaluated essay with number: 146
# It will evaluated essay with number:147
# Evaluated essay with number: 147
# It will evaluated essay with number:148
# Não há informações suficientes para fornecer notas.
# Evaluated essay with number: 148
# It will evaluated essay with number:149
# Evaluated essay with number: 149
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 1
#
#
# Processed essays from 140 to: 150
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 150}
# It will evaluated essay with number:150
# Evaluated essay with number: 150
# It will evaluated essay with number:151
# Evaluated essay with number: 151
# It will evaluated essay with number:152
# Evaluated essay with number: 152
# It will evaluated essay with number:153
# Não posso fornecer notas sem uma resposta anterior. Como essa é a primeira interação, não há dados para calcular as notas.
# Evaluated essay with number: 153
# It will evaluated essay with number:154
# Não há resposta anterior para fornecer as notas.
# Não há resposta anterior para fornecer as notas.
# Evaluated essay with number: 154
# It will evaluated essay with number:155
# Evaluated essay with number: 155
# It will evaluated essay with number:156
# Evaluated essay with number: 156
# It will evaluated essay with number:157
# Evaluated essay with number: 157
# It will evaluated essay with number:158
# There was an exception on made question: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}
# Não posso fornecer notas quantitativas com base em dados inexistentes.
# Evaluated essay with number: 158
# It will evaluated essay with number:159
# Evaluated essay with number: 159
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 2
#
#
# Processed essays from 150 to: 160
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 160}
# It will evaluated essay with number:160
# Evaluated essay with number: 160
# It will evaluated essay with number:161
# Não posso fornecer notas sem um texto ou dados para avaliar.
# Evaluated essay with number: 161
# It will evaluated essay with number:162
# Evaluated essay with number: 162
# It will evaluated essay with number:163
# Não há dados suficientes para fornecer uma resposta precisa.
# Evaluated essay with number: 163
# It will evaluated essay with number:164
# Evaluated essay with number: 164
# It will evaluated essay with number:165
# Evaluated essay with number: 165
# It will evaluated essay with number:166
# Não há dados para fornecer notas.
# Não tenho uma resposta anterior para referenciar. Como não há dados adicionais para avaliar, não posso fornecer notas.
# Evaluated essay with number: 166
# It will evaluated essay with number:167
# Evaluated essay with number: 167
# It will evaluated essay with number:168
# Não há dados suficientes para calcular as notas.
# Evaluated essay with number: 168
# It will evaluated essay with number:169
# Não tenho informações suficientes para fornecer as notas. Não há dados anteriores para utilizar como base de cálculo.
# Não tenho uma resposta anterior para basear as notas. Como não há informação anterior, não posso fornecer as notas.
#
# Se você fornecer uma tarefa ou texto para ser avaliado, posso fornecer as notas.
# Evaluated essay with number: 169
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 3
#
#
# Processed essays from 160 to: 170
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 170}
# It will evaluated essay with number:170
# Não há dados suficientes para fornecer as notas quantitativas. Não posso fornecer uma resposta baseada apenas na sua solicitação.
# 400,0
# Não foram fornecidos dados suficientes para avaliar as competências.
# Evaluated essay with number: 170
# It will evaluated essay with number:171
# Não posso fornecer notas sem um trecho de texto para avaliar. Se você fornecer um texto, posso avaliar e fornecer as notas de acordo com o formato solicitado.
# Não posso fornecer notas quantitativas sem uma prova ou texto para avaliar.
# Não tenho dados anteriores para fornecer as notas. Favor forneça os dados necessários para calcular as notas.
# Não é possível fornecer notas sem uma tarefa ou resposta anterior para avaliar. Não há dados suficientes para fornecer uma resposta.
# Evaluated essay with number: 171
# It will evaluated essay with number:172
# Evaluated essay with number: 172
# It will evaluated essay with number:173
# 0
# Evaluated essay with number: 173
# It will evaluated essay with number:174
# Evaluated essay with number: 174
# It will evaluated essay with number:175
# Evaluated essay with number: 175
# It will evaluated essay with number:176
# Evaluated essay with number: 176
# It will evaluated essay with number:177
# Não há dados para calcular as notas.
# Infelizmente, não há dados disponíveis para gerar notas.
# Como não há dados anteriores, não posso fornecer notas.
# Não é possível fornecer notas quantitativas sem ter acesso a uma resposta anterior. Como não há dados anteriores, não posso fornecer uma resposta numérica nesse formato.
# Sem dados para avaliar, não posso fornecer notas.
# Não foi possível fornecer uma nota pois não há resposta anterior.
# Evaluated essay with number: 177
# It will evaluated essay with number:178
# Evaluated essay with number: 178
# It will evaluated essay with number:179
# Evaluated essay with number: 179
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 4
#
#
# Processed essays from 170 to: 180
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 180}
# It will evaluated essay with number:180
# Evaluated essay with number: 180
# It will evaluated essay with number:181
# Evaluated essay with number: 181
# It will evaluated essay with number:182
# Evaluated essay with number: 182
# It will evaluated essay with number:183
# Evaluated essay with number: 183
# It will evaluated essay with number:184
# Esse é o meu primeiro contato com o usuário. Não tenho nenhuma resposta anterior para fornecer as notas. Posso iniciar uma nova avaliação, se desejar.
# Evaluated essay with number: 184
# It will evaluated essay with number:185
# Evaluated essay with number: 185
# It will evaluated essay with number:186
# Não foi fornecida nenhuma resposta anterior. Portanto, não posso fornecer notas. Se você quiser fornecer uma resposta ou texto, posso avaliar e fornecer as notas.
# Evaluated essay with number: 186
# It will evaluated essay with number:187
# Não posso fornecer notas sem uma resposta anterior. Como não há informações para analisar, não posso fornecer as notas. Se quiser, posso simular uma resposta com base em um texto genérico. Se preferir, posso fazer isso.
# Não tenho informações suficientes para fornecer notas.
# Evaluated essay with number: 187
# It will evaluated essay with number:188
# Não posso fornecer uma resposta nesse caso.
# Evaluated essay with number: 188
# It will evaluated essay with number:189
# Como não tenho nenhuma resposta anterior para basear, não posso fornecer notas.
# Evaluated essay with number: 189
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 5
#
#
# Processed essays from 180 to: 190
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 190}
# It will evaluated essay with number:190
# Não há dados disponíveis para fornecer notas.
# Não possuo dados suficientes para fornecer notas. Posso apenas informar que não foi possível calcular as notas.
# Como não há dados adicionais, não posso fornecer notas.
# Evaluated essay with number: 190
# It will evaluated essay with number:191
# Evaluated essay with number: 191
# It will evaluated essay with number:192
# Evaluated essay with number: 192
# It will evaluated essay with number:193
# Evaluated essay with number: 193
# It will evaluated essay with number:194
# Como não há dados anteriores para referencia, não posso fornecer as notas. Para fornecer as notas, é necessário ter dados anteriores ou uma resposta específica para avaliar.
# Evaluated essay with number: 194
# It will evaluated essay with number:195
# Evaluated essay with number: 195
# It will evaluated essay with number:196
# Evaluated essay with number: 196
# It will evaluated essay with number:197
# Evaluated essay with number: 197
# It will evaluated essay with number:198
# Evaluated essay with number: 198
# It will evaluated essay with number:199
# Evaluated essay with number: 199
#
#
#  Setting model llama-3.2-90b-text-preview with API Key 1
#
#
# Processed essays from 190 to: 200
# Saving state: {'Model': 2, 'Database': 2, 'Experimento': 5, 'Execucao': 5, 'MaxExecucao': 5, 'Batch': 200}
# It will evaluated essay with number:200
# Evaluated essay with number: 200
# It will evaluated essay with number:201
# Evaluated essay with number: 201
# It will evaluated essay with number:202
# Não há resposta anterior para basear as notas.
# Infelizmente, não tenho dados suficientes para fornecer as notas. Por favor, forneça as respostas que gostaria que eu avaliasse.
# Evaluated essay with number: 202
# It will evaluated essay with number:203
# Não tenho informações suficientes para fornecer notas.
# Evaluated essay with number: 203
# It will evaluated essay with number:204
# Evaluated essay with number: 204
# It will evaluated essay with number:205
# Evaluated essay with number: 205
# It will evaluated essay with number:206
# There was an exception on made question: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.2-90b-text-preview` in organization `org_01jcrrx836eshv8r1mhyzevhc7` on : Limit 500000, Used 500304, Requested 633. Please try again in 2m42.0698s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
# There was an exception on run_experiment!!: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.2-90b-text-preview` in organization `org_01jcrrx836eshv8r1mhyzevhc7` on : Limit 500000, Used 500478, Requested 120. Please try again in 1m43.354999999s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': '', 'code': 'rate_limit_exceeded'}}
